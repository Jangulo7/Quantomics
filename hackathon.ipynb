# %% [markdown]
# # Hackathon Quantum Madrid × UPM

# %%
# Create a quantum circuit with 2 qubits and apply a Hadamard gate 
from qiskit import QuantumCircuit

# Create a quantum circuit with 2 qubits
qc = QuantumCircuit(2)

# Apply Hadamard gate to the first qubit
qc.h(0)

# Display the circuit
qc.draw('mpl')

# %% [markdown]
# ## Ejemplo: Bell State con Qiskit Code Assistant
#
# Ahora vamos a crear un **estado de Bell** (entrelazamiento cuántico):
# - Usa `Ctrl + I` en la siguiente celda y escribe: "create a bell state"

# %%
# Create a Bell state
qc_bell = QuantumCircuit(2)

# Apply Hadamard gate to the first qubit
qc_bell.h(0)

# Apply CNOT gate with qubit 0 as control and qubit 1 as target
qc_bell.cx(0, 1)

# Display the circuit
qc_bell.draw('mpl')
